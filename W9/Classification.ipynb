# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix ,accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectPercentile   , chi2
from sklearn.naive_bayes import GaussianNB,MultinomialNB

# %%
df=pd.read_csv('mobilePriceRange.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
print(x.shape ,y.shape)
# Out:
# (2000, 20) (2000,)

# %%
selector=SelectPercentile(score_func=chi2,percentile=50)
newX=selector.fit_transform(x,y)
print(newX.shape ,y.shape)
# Out:
# (2000, 10) (2000,)

# %%
selectedColumns=selector.get_feature_names_out().tolist()
print(x.head())
x=pd.DataFrame(columns=selectedColumns,data=newX)
print(x.head())
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0, shuffle =True)
print('x_train shape is ' , x_train.shape)
print('y_train shape is ' , y_train.shape)
print('x_test shape is ' , x_test.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# x_train shape is  (1500, 10)
# y_train shape is  (1500,)
# x_test shape is  (500, 10)
# y_test shape is  (500,)

# %%
clfs={}
clfs['GaussianNB']=GaussianNB()
clfs['MultinomialNB']=MultinomialNB()
clfs['DecisionTree[entropy]']=DecisionTreeClassifier(criterion='entropy' ,random_state=0) 
clfs['DecisionTree[gini]']=DecisionTreeClassifier(criterion='gini' ,random_state=0)

# %%
accuracyScoreTest={}
accuracyScoreTestAdjusted={}
accuracyScoreTrain={}
accuracyScoreTrainAdjusted ={}
confusionMatrix={}
n=x_train.shape[0]
p=x_train.shape[1]
for i in clfs:
    clfs[i].fit(x_train,y_train)
    y_pred=clfs[i].predict(x_test)
    accuracyScoreTrain[i]=clfs[i].score(x_train,y_train)
    accuracyScoreTrainAdjusted[i]=1-(1-accuracyScoreTrain[i])*(n-1)/(n-p-1)
    accuracyScoreTest[i]= accuracy_score(y_true=y_test, y_pred=y_pred)
    accuracyScoreTestAdjusted[i]=1-(1-accuracyScoreTest[i])*(n-1)/(n-p-1)
    confusionMatrix[i]=confusion_matrix(y_true=y_test, y_pred=y_pred)

# %%
ndf=pd.DataFrame(data=accuracyScoreTrain.values(),columns=['Score(train)'],index=accuracyScoreTrain.keys())
ndf['AdjustedScore(train)']=accuracyScoreTrainAdjusted.values()
ndf['Score(test)']=accuracyScoreTest.values()
ndf['AdjustedScore(test)']=accuracyScoreTestAdjusted.values()
ndf
# Out:
#                        Score(train)  AdjustedScore(train)  Score(test)  \
# GaussianNB                 0.805333              0.804026        0.832
# MultinomialNB              0.522000              0.518790        0.530
# DecisionTree[entropy]      1.000000              1.000000        0.854
# DecisionTree[gini]         1.000000              1.000000        0.830
#
#                        AdjustedScore(test)
# GaussianNB                        0.830872
# MultinomialNB                     0.526844
# DecisionTree[entropy]             0.853019
# DecisionTree[gini]                0.828858

# %%
for i in confusionMatrix:
    sns.heatmap(confusionMatrix[i],annot=True,fmt='.1f')
    plt.title(i)
    plt.show()
